# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiaa-santos/BD/blob/main/aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AULA 02 - BIBLIOTECAS PYTHON

# %% [markdown]
# ##PANDAS

# %%
import pandas as pd

# %%
titanic = pd.read_csv("/titanic.csv", sep=",")

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic["Name"].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
filtro = ["Name", "Sex", "Age"]
titanic[filtro].head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
titanic.iloc[5:11,3:6]
# Out:
#                                                  Name     Sex   Age
# 5                                    Moran, Mr. James    male   NaN
# 6                             McCarthy, Mr. Timothy J    male  54.0
# 7                      Palsson, Master. Gosta Leonard    male   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
titanic.loc[:, ["Survived", "Name", "Age"]]
# Out:
#      Survived                                               Name   Age
# 0           0                            Braund, Mr. Owen Harris  22.0
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2           1                             Heikkinen, Miss. Laina  26.0
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4           0                           Allen, Mr. William Henry  35.0
# ..        ...                                                ...   ...
# 886         0                              Montvila, Rev. Juozas  27.0
# 887         1                       Graham, Miss. Margaret Edith  19.0
# 888         0           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889         1                              Behr, Mr. Karl Howell  26.0
# 890         0                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 3 columns]

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic.Age.max()
# Out:
# 80.0

# %%
titanic.iloc[122:123, :]
# Out:
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 122          123         0       2  Nasser, Mr. Nicholas  male  32.5      1
#
#      Parch  Ticket     Fare Cabin Embarked
# 122      0  237736  30.0708   NaN        C

# %%
x = titanic.dropna()
x.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 52           53         1       1
# 54           55         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
x.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
media_idade = titanic["Age"].mean()
media_idade
# Out:
# np.float64(29.69911764705882)

# %%
y = titanic["Age"].fillna(media_idade)
y.head(10)
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %%
filtro_sobreviveu = titanic["Survived"] == 1
sobreviventes = titanic[filtro_sobreviveu].head(30)
sobreviventes.describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    30.000000      30.0  30.000000  21.000000  30.000000  30.000000
# mean     32.733333       1.0   2.166667  27.571429   0.400000   0.433333
# std      20.379052       0.0   0.833908  15.619127   0.498273   1.072648
# min       2.000000       1.0   1.000000   3.000000   0.000000   0.000000
# 25%      16.500000       1.0   1.250000  15.000000   0.000000   0.000000
# 50%      30.500000       1.0   2.000000  28.000000   0.000000   0.000000
# 75%      51.750000       1.0   3.000000  38.000000   1.000000   0.000000
# max      67.000000       1.0   3.000000  58.000000   1.000000   5.000000
#
#              Fare
# count   30.000000
# mean    28.698613
# std     30.676409
# min      7.225000
# 25%      8.646900
# 50%     15.622900
# 75%     34.471875
# max    146.520800

# %%
filtro_sexo = titanic["Sex"] == "female"

# %%
sobreviventes_mulheres = titanic[filtro_sobreviveu & filtro_sexo]
sobreviventes_mulheres.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   233.000000     233.0  233.000000  197.000000  233.000000  233.000000
# mean    429.699571       1.0    1.918455   28.847716    0.515021    0.515021
# std     255.048296       0.0    0.834211   14.175073    0.737533    0.820527
# min       2.000000       1.0    1.000000    0.750000    0.000000    0.000000
# 25%     238.000000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     400.000000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     636.000000       1.0    3.000000   38.000000    1.000000    1.000000
# max     888.000000       1.0    3.000000   63.000000    4.000000    5.000000
#
#              Fare
# count  233.000000
# mean    51.938573
# std     64.102256
# min      7.225000
# 25%     13.000000
# 50%     26.000000
# 75%     76.291700
# max    512.329200
